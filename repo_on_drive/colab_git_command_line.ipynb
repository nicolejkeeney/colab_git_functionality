# %% [markdown]
# For pushing and pulling changes from GitHub

# %%
COMMIT_MESSAGE = "testing access key stuff"

# %%
from google.colab import drive    # Mount Google Drive
ROOT = "/content/drive"           # Default location for the drive
drive.mount(ROOT)                 # Mount the google drive at location specified by ROOT
# Out:
# Mounted at /content/drive

# %%
MY_GOOGLE_DRIVE_PATH = 'My Drive/github'     # Path to your project on Google Drive

GIT_USERNAME = "nicolejkeeney" 
GIT_EMAIL = "nicolejkeeney@gmail.com"
GIT_REPOSITORY = "colab_git_integration" 

REPOSITORY_PATH_ON_DRIVE = ROOT + '/' + MY_GOOGLE_DRIVE_PATH + '/' + GIT_REPOSITORY      # Location of repository on google drive

# Navigate to repo location
# %cd "{REPOSITORY_PATH_ON_DRIVE}"
# Out:
# /content/drive/My Drive/github/colab_git_integration

# %% [markdown]
# Use !git config --list to check that name, email, and token stored in the remote_origin_url are correct. The numbers at the beginning of remote.origin.url should match your private token

# %%
# Configure GitHub user details
# !git config --global user.email "{GIT_EMAIL}"
# !git config --global user.name "{GIT_USERNAME}"

#!git config --list

# %%
# !git add .

# %%
# !git commit -m "{COMMIT_MESSAGE}"

# %%
# !git push
